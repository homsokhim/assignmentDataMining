# %%
import csv
import pandas as pd

# %%
filename = 'newsCorpora.csv'
df = pd.read_csv(filename, encoding='utf-8', quoting=csv.QUOTE_ALL, low_memory=False, sep='\t', header=None, names=['ID', 'TITLE', 'URL', 'PUBLISHER', 'CATEGORY', 'STORY', 'HOSTNAME', 'TIMESTAMP'])

# %%
df.head()
# Out:
#                                                   ID  \
# 0  1\tFed official says weak data caused by weath...
# 1  2\tFed's Charles Plosser sees high bar for cha...
# 2  3\tUS open: Stocks fall after Fed official hin...
# 3  4\tFed risks falling 'behind the curve'," Char...
# 4  5\tFed's Plosser: Nasty Weather Has Curbed Job...
#
#                                                TITLE                URL  \
# 0  http://www.latimes.com/business/money/la-fi-mo...  Los Angeles Times
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3  http://www.ifamagazine.com/news/fed-risks-fall...       IFA Magazine
# 4                                                NaN                NaN
#
#   PUBLISHER                       CATEGORY                STORY  \
# 0         b  ddUyU0VZz0BRneMioxUPQVP6sIxvM      www.latimes.com
# 1       NaN                            NaN                  NaN
# ...
